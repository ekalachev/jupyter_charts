# %%
import numpy as np
import pandas as pd
import time

import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Parabola
#
# $$
# f(x) = x^2
# $$

# %%
# Set plot size
fig = plt.figure(figsize=(10, 6))

plt.title(r'Parabola: $y = x^{2}$', fontsize=18, loc='right')
plt.ylabel('f(x)', fontsize=14)
plt.xlabel('x', fontsize=14)

plt.grid(True)
plt.axhline(0, color='black')
plt.axvline(0, color='black')

# х - аргумент в нашей функции.
# передадим начало и конец числового отрезка нашей функции и шаг аргумента:
x = np.arange(-10, 10.01, 0.01)

plt.plot(x, x**2)

plt.show()

# %% [markdown]
# # Natural logarithm
# $$
# f(x) = ln(x)
# $$

# %%
# Set plot size
fig = plt.figure(figsize=(8, 6))

plt.title('Natural logarithm: y = ln(x)', fontsize=18, loc='right')
plt.ylabel('f(x)', fontsize=14)
plt.xlabel('x', fontsize=14)

plt.grid(True)

x = np.arange(1, 100, 0.01)

plt.plot(x, np.log(x))

plt.show()

# %% [markdown]
# # Exponent
#
# $$
# f(x) = e^x
# $$

# %%
# Set plot size
fig = plt.figure(figsize=(10, 6))

plt.ylabel('f(x)', fontsize=14)
plt.xlabel('x', fontsize=14)
plt.title(r'Exponent: $y = e^{x}$', fontsize=18, loc='right')

plt.grid(True)

x = np.arange(-3, 3, 0.01)
plt.plot(x, np.e**x)

plt.show()

# %% [markdown]
# # The standard normal probability density function
#
# $$
# f(x) = \frac{1}{\sqrt{2\pi}} e^{-\frac{x^2}{2}}
# $$

# %%
def get_standard_normal_probability_density_function(x):
    return (1/np.sqrt(2 * np.pi)) * np.e**(-(x**2 / 2))


# Set plot size
fig = plt.figure(figsize=(12, 6))

plt.title(
    r'The standard normal probability density function: $f(x) = \dfrac{1}{\sqrt{2\pi}} e^{-\dfrac{x^2}{2}}$',
    fontsize=18
)
plt.ylabel('f(x)', fontsize=14)
plt.xlabel('x', fontsize=14)

plt.grid(True)

x = np.arange(-6, 6, 0.01)
plt.plot(x, get_standard_normal_probability_density_function(x))

plt.show()

# %% [markdown]
# # Sigmoid
#
# $$
# f(x) = \frac{1}{1 + e^{-\alpha x}}
# $$

# %%
def get_sigmoid(x, alpha):
    return 1/(1 + np.e**(-alpha * x))


# Set plot size
fig = plt.figure(figsize=(10, 6))

plt.title(r'Sigmoid: $f(x) = \dfrac{1}{1 + e^{-\alpha x}}$', fontsize=18, loc='right')
plt.ylabel('f(x)', fontsize=14)
plt.xlabel('x', fontsize=14)

plt.grid(True)

x = np.arange(-1, 1, 0.01)

plt.plot(x, get_sigmoid(x, 5))
plt.plot(x, get_sigmoid(x, 10))
plt.plot(x, get_sigmoid(x, 15))

plt.legend([
    r'$f(x) = \dfrac{1}{1 + e^{-5 x}}$',
    r'$f(x) = \dfrac{1}{1 + e^{-10 x}}$',
    r'$f(x) = \dfrac{1}{1 + e^{-15 x}}$'
])

plt.axhline(0, color='black', lw=1.2)
plt.axvline(0, color='black', lw=1.2)

plt.show()

# %% [markdown]
# # Arctan
#
# $$
# f(x) = arctan(x)
# $$

# %%
# Set plot size
fig = plt.figure(figsize=(16, 6))

plt.title('Natural logarithm: y = arctan(x)', fontsize=18)
plt.ylabel('f(x)', fontsize=14)
plt.xlabel('x', fontsize=14)

plt.grid(True)
plt.axhline(0, color='black', lw=1.2)
plt.axvline(0, color='black', lw=1.2)

x = np.arange(-5, 5, 0.01)

plt.plot(x, np.arctan(x))

plt.show()

# %% [markdown]
# # Sine waves
#
# $$
# f(x) = sin(x)
# $$

# %%
# Set plot size
fig = plt.figure(figsize=(16, 6))

plt.title('Sine waves: y = sin(x)', fontsize=18)
plt.ylabel('f(x)', fontsize=14)
plt.xlabel('x', fontsize=14)

plt.grid(True)
plt.axhline(0, color='black', lw=1.2)
plt.axvline(0, color='black', lw=1.2)

x = np.arange(-20, 20, 0.01)

plt.plot(x, np.sin(x))

plt.show()

# %% [markdown]
# # Min-Max for x,y

# %%
# Set plot size
fig = plt.figure(figsize=(6,4))

plt.title('Set min-max for axis', fontsize=18)
plt.ylabel('f(x)', fontsize=14)
plt.xlabel('x [-0.5, ... , 1]', fontsize=14)

plt.grid(True)

x = np.arange(-0.5, 1, 0.01)

plt.plot(x, -5 * x**2 + 3 * x + 100)

plt.legend([
    r'$f(x) = -5x^{2} + 3x + 100$'
])

plt.axhline(0, color='black', lw=1.2)
plt.axvline(0, color='black', lw=1.2)

plt.ylim([96, 102])
plt.xlim([-0.6, 1.1])

plt.show()
